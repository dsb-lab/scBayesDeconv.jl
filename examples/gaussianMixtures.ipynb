# %%
import scBayesDeconv 
using Distributions
using Random
using Plots
# Out:
# ┌ Info: Precompiling scBayesDeconv [ba4b0364-d62a-4552-92b1-eb0a52360a94]
# └ @ Base loading.jl:1342
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1342

# %%
# Generate data
d = MixtureModel(
    MultivariateNormal[
        MultivariateNormal([0; 1],[1 .5;.5 1]),
        MultivariateNormal([3; 1],[1 .5;.5 1])
    ],
    [.5,.5]
    )

X = Matrix(transpose(rand(d,1000)));

# %%
scatter(X[:,1],X[:,2])

# %%
dists,ind = finiteGaussianMixture(X,1)

# %%
scBayesDeconv.finiteGaussianMixtureEM(X,k=1)
# Out:
# UndefVarError: kmeans_ not defined
#
# Stacktrace:
#  [1] finiteGaussianMixtureEM(X::Matrix{Float64}; k::Int64, initialization::String, maximumSteps::Int64)
#    @ scBayesDeconv ~/Documents/scBayesDeconv.jl/src/gaussianMixture.jl:74
#  [2] top-level scope
#    @ In[36]:1
#  [3] eval
#    @ ./boot.jl:360 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116
